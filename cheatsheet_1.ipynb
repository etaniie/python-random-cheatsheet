# %%
var1 = ' I love python '

# %%
print(var1)
# Out:
#  I love python

# %%
var1 = ' I love coding in python '
print(var1)
# Out:
#  I love coding in python

# %%
VAR2 = 'I love myself'
Var1 = 'I am a biologist'

# %%
print(VAR2)
# Out:
# I love myself

# %% [markdown]
# ## numeric operations on python
# -- we will study mathematical operations using python
# -- we will have some example to better grasp the concept

# %%
# Addition 

num_1 = 2
num_2 = 4

sum_1_2 = num_1 + num_2 

print(sum_1_2)
# Out:
# 6

# %%
num_3 = 2.2
num_4 = 4.2

sum_3_4 = num_3 + num_4
print(sum_3_4)
# Out:
# 6.4

# %%
type(num_3)
# Out:
# float

# %%
type(num_1)
# Out:
# int

# %%
#subtraction
num_5 = 4.2
num_6 = 3.3

diff_5_6 = num_5 - num_6

print(diff_5_6)
# Out:
# 0.9000000000000004

# %%
# multiplication
num_7 = 3.3
num_8 = 2

mul_7_8 = num_7 * num_8

print(mul_7_8)
# Out:
# 6.6

# %%
# division
num_7 = 4
num_8 = 2

div_7_8 = num_7 / num_8

print(div_7_8)
# Out:
# 2.0

# %%
# division - quotient
num_7 = 8
num_8 = 7

div_7_8_quotient = num_7 // num_8

print(div_7_8_quotient)
# Out:
# 1

# %%
# division - remainder
num_7 = 8
num_8 = 7

div_7_8_remainder = num_7 % num_8

print(div_7_8_remainder)
# Out:
# 1

# %%
# complex numbers
comp_a = complex(2, 3)
print(comp_a)
# Out:
# (2+3j)

# %%
comp_b = 2+3j
print(comp_b)
# Out:
# (2+3j)

# %%
3>4
# Out:
# False

# %%
3>2
# Out:
# True

# %%
a = 3
b = 5
c = 7
d = 0

a>b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
c != d
# Out:
# True

# %%
b >= d
# Out:
# True

# %%
print(a ** b)
# Out:
# 243

# %% [markdown]
# # string in python

# %%
# storing a string in a variable 

First_string = " we will study the basics of string datatype in this class "
Second_string = ' here we will study about string manipulation methods ' 

print(First_string)
print(Second_string)
# Out:
#  we will study the basics of string datatype in this class
#  here we will study about string manipulation methods

# %%
third_string = " we will study the basics of 'string' datatype in this class "
fourth_string = ' here we will study about "string" manipulation methods ' 

print(third_string)
print(fourth_string)
# Out:
#  we will study the basics of 'string' datatype in this class
#  here we will study about "string" manipulation methods

# %%
num_a = 23
num_b = '23'

print(type(num_a))
print(type(num_b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Type casting

num_a = 23
num_a_as_str = str(num_a)

print(num_a)
print(type(num_a))
print(num_a_as_str)
print(type(num_a_as_str))
# Out:
# 23
# <class 'int'>
# 23
# <class 'str'>

# %%
num_string = '45'
print(num_string)
print(type(num_string))

num_string_as_num = int(num_string)
print(num_string_as_num)
print(type(num_string_as_num))
# Out:
# 45
# <class 'str'>
# 45
# <class 'int'>

# %% [markdown]
# # string analysis in python

# %%
Protein_seq1 = 'VLSPADKTNVK'

# len(): this command allows us to calculate the length of a given string

Protein_seq1_len = len(Protein_seq1)

Protein_seq1_len
# Out:
# 11

# %%
# splicing 
# amino asid at position 9
Protein_seq1[0]
# Out:
# 'V'

# %%
Protein_seq1[8]
# Out:
# 'N'

# %%
Protein_seq1[len(Protein_seq1)-1]
# Out:
# 'K'

# %%
# splice a subpart of a string 

# variable_name[start_index:(end_index+1)]

Protein_seq1[1:(5+1)]
# Out:
# 'LSPAD'

# %%
Protein_seq1[1:(5+1):1]
# Out:
# 'LSPAD'

# %%
Protein_seq1[1:(5+1):2]
# Out:
# 'LPD'

# %%
Protein_seq1[1:(5+1):3]
# Out:
# 'LA'

# %%
Protein_seq1 = 'VLSPADKTNVK'
Protein_seq1[-1]
# Out:
# 'K'

# %%
Protein_seq1[:(5+1)]
# Out:
# 'VLSPAD'

# %%
Protein_seq1[2:]
# Out:
# 'SPADKTNVK'

# %%
Protein_seq1[:]
# Out:
# 'VLSPADKTNVK'

# %%
# how can we flip the sequence horizontally 

Protein_seq1 = 'VLSPADKTNVK'

Protein_seq1[::-1]
# Out:
# 'KVNTKDAPSLV'

# %%
Protein_seq1[::1]
# Out:
# 'VLSPADKTNVK'

# %%
# concatenation

DNA_fragment1 = 'AATGC'
DNA_fragment2 = 'TTGGC'

full_DNA_seq = DNA_fragment1 + DNA_fragment2

print(full_DNA_seq)
# Out:
# AATGCTTGGC

# %%
# repeat disorder

rep_seq = 'GGGGCC' 
rep_len = 4

actual_rep_seq = '(' + rep_seq + ')' +  str(rep_len)

actual_rep_seq
# Out:
# '(GGGGCC)4'

# %%
# concatenating string, 2nd approach

actual_rep_seq = f"({rep_seq}){str(rep_len)}"
actual_rep_seq
# Out:
# '(GGGGCC)4'

# %% [markdown]
# # Case change in python

# %%
DNA_upper = 'ATTGGCCCG'
DNA_lower = 'attggca'

# .lower() 
DNA_upper_to_lower = DNA_upper.lower()
print(f"DNA upper is '{DNA_upper}' and after applying .lower() method, it became '{DNA_upper_to_lower}' ")
# Out:
# DNA upper is 'ATTGGCCCG' and after applying .lower() method, it became 'attggcccg'

# %%
# .upper() 

DNA_lower_to_upper = DNA_lower.upper()

print(DNA_lower_to_upper)
# Out:
# ATTGGCA

# %%
print(f"DNA lower is '{DNA_lower}' and after applying .upper() method, it became '{DNA_lower_to_upper}' ")
# Out:
# DNA lower is 'attggca' and after applying .upper() method, it became 'ATTGGCA'

# %%
# title mode = .title()

Simulation_name = 'molecular dynamics simulation'
Simulation_name_formatted = Simulation_name.title()
Simulation_name_formatted
# Out:
# 'Molecular Dynamics Simulation'

# %%
print(f'Simulation name before: {Simulation_name}, after applying .title() method, it became: {Simulation_name_formatted}')
# Out:
# Simulation name before: molecular dynamics simulation, after applying .title() method, it became: Molecular Dynamics Simulation

# %%
# sentence mode = .capitalize()

to_capitalize = 'i am enjoying python programming.' 

to_capitalize_format = to_capitalize.capitalize()

print(f'Before format = {to_capitalize}, after applying .capitalize(), it became {to_capitalize_format}')
# Out:
# Before format = i am enjoying python programming., after applying .capitalize(), it became I am enjoying python programming.

# %% [markdown]
# # replace

# %%
Protein_WT = 'VLSPADKTNVWWWYY' 

mutant_1 = Protein_WT.replace('W','M')
print(mutant_1)

mutant_2 = Protein_WT.replace('W','M', 1)
print(mutant_2)

mutant_3 = Protein_WT.replace('W','M', 2)
print(mutant_3)
# Out:
# VLSPADKTNVMMMYY
# VLSPADKTNVMWWYY
# VLSPADKTNVMMWYY

# %%
general_example = ' I am enjoying python programming and i will use it to analyse biological data'

general_example_modified = general_example.replace('analyse', 'analyze')

print(general_example_modified)
# Out:
#  I am enjoying python programming and i will use it to analyze biological data

# %% [markdown]
# # find and count

# %%
Protein = 'VLSPADKTNVWWWYY' 

# .find() method

proline_occurrence = Protein.find('P') 
print(proline_occurrence)
# Out:
# 3

# %%
Protein = 'VLSPADKTNVWWWYY' 

# .count() method

tryptophan_occurrence = Protein.count('W')
print(tryptophan_occurrence)
# Out:
# 3

# %%
Protein.count('X')
# Out:
# 0

# %% [markdown]
# # split and join

# %%
# split.()
string_to_split = 'Biology is interesting, I am using python to analyze biological data'

splitting_string_attempt1 = string_to_split.split()
print(splitting_string_attempt1)
# Out:
# ['Biology', 'is', 'interesting,', 'I', 'am', 'using', 'python', 'to', 'analyze', 'biological', 'data']

# %%
splitting_string_attempt2 = string_to_split.split(',')
print(splitting_string_attempt2)
# Out:
# ['Biology is interesting', ' I am using python to analyze biological data']

# %%
# .join()

splitting_string_attempt1_recombine = ','.join(splitting_string_attempt1)
print(splitting_string_attempt1_recombine)
# Out:
# Biology,is,interesting,,I,am,using,python,to,analyze,biological,data

# %%
splitting_string_attempt1_recombine2 = ' '.join(splitting_string_attempt1)
print(splitting_string_attempt1_recombine2)
# Out:
# Biology is interesting, I am using python to analyze biological data

# %%
splitting_string_attempt2_recombine = '.'.join(splitting_string_attempt2)
print(splitting_string_attempt2_recombine)
# Out:
# Biology is interesting. I am using python to analyze biological data

# %% [markdown]
# # strip

# %%
temp_1 = 'Python'
temp_2 = " Python "

# %%
temp_1
# Out:
# 'Python'

# %%
temp_2
# Out:
# ' Python '

# %%
#replace

temp_2.replace(" ","")
# Out:
# 'Python'

# %%
temp_2 = " Python is an interesting programming language. "
temp_2
# Out:
# ' Python is an interesting programming language. '

# %%
temp_2.replace(" ","")
# Out:
# 'Pythonisaninterestingprogramminglanguage.'

# %%
# strip

temp_2_cleaned = temp_2.strip()
temp_2_cleaned
# Out:
# 'Python is an interesting programming language.'

# %%
temp_2_cleaned_l = temp_2.lstrip()
temp_2_cleaned_l
# Out:
# 'Python is an interesting programming language. '

# %%
temp_3 = ";Python is an interesting programming language; it is fun to learn it.;"

# %%
temp_3.strip(';')
# Out:
# 'Python is an interesting programming language; it is fun to learn it.'

# %%
temp_3.rstrip(';')
# Out:
# ';Python is an interesting programming language; it is fun to learn it.'

# %%
temp_3.lstrip(';')
# Out:
# 'Python is an interesting programming language; it is fun to learn it.;'
